# %% [markdown]
# # UC 1: Calculate Length of Line

# %%
import math

def line_lenght(x1,x2,y1,y2):
    return math.sqrt((x2-x1)**2 + (y2-y1)**2)

x1 = float(input("Enter the x1 : "))
x2 = float(input("Enter the x2 : "))
y1 = float(input("Enter the y1 : "))
y2 = float(input("Enter the y2 : "))

length = line_lenght(x1,x2,y1,y2)
print("\nLength of line is :",length)
# Out:
# Enter the x1 : 1
# Enter the x2 : 2
# Enter the y1 : 4
# Enter the y2 : 6
#
# Length of line is : 2.23606797749979
